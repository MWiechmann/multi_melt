# %%
import pandas as pd

test = pd.read_excel("test.xlsx")

# %%
cols = list(test.columns)
cols.remove("record")

# %%
wide = test.pivot_table(columns = "record", aggfunc= "first")

# %%
wide[20:30]
# Out:
# record                       34883 34885    34889  \
# QADAW01r8                     None  None     None
# QADAW01r9                     None  None     None
# QADAWb_b1                     None  None     None
# QADAWb_b2      هناك خصم على الشياء  None     None
# QADAWb_b3                     None  None     None
# QADAWb_b4                     None  None  Günstig
# QBRAW01RECr1                     3     2        2
# QBRAW01RECr10                   99    99       99
# QBRAW01RECr2                    99     7        7
# QBRAW01RECr3                    99     6        5
#
# record                                 34891 34893  \
# QADAW01r8                               None  None
# QADAW01r9                               None  None
# QADAWb_b1                               None  None
# QADAWb_b2                               None  None
# QADAWb_b3      Angebote über Obst und Gemüse  None
# QADAWb_b4                               None  None
# ...
